# %%
print("===soal no1=====")

sa = 0
sb = 1
sc = 4
sd = 7
se = 5
sf = 0
s2 = (sa + sb + sc + sd + se + sf )
print("jumlah s2: " + str(s2))

sg = 4
sh = 12
si = 6
sj = 13
sk = 14
sl = 0
s1 = (sg + sh + si + sj + sk + sl )
print("jumlah s1: " + str(s1))

a = 12
a1 = 17
a2 = 5
a3 = 20
a4 = 11
a5 = 75
sma = (a + a1 + a2 + a3 + a4 + a5 )
print("jumlah sma: " + str(sma))

z = 5
x = 6
c = 15
v = 9
b = 20
n = 15
smp = (z + x + c + v + b + n )
print("jumlah smp: " + str(smp))

a = 1
b = 8
c = 0
d = 19
e = 10
f = 1
sd = (a + b + c + d + e + f )
print("jumlah sd: " + str(sd))

a1 = 2
a2 = 14
a4 = 3
a5 = 10
a6 = 0
a7 = 1
tdk = (a1 + a2 + a4 + a5 + a6 + a7 )
print("jumlah tdk: " + str(tdk))
print()
print("====soal no2======")
S2s =   0.25
S1s =   0.2
SMA = 0.15
SMP =   0.10
SD =    0.05
TDK= 0.03
print("maka hasil indek s2 adalah: " + str(s2 * S2s))
print("maka hasil indek s1 adalah: " + str(s1 * S1s))
print("maka hasil indek sma adalah: " + str(sma * SMA))
print("maka hasil indek smp adalah: " + str(smp * SMP))
print("maka hasil indek sd adalah: " + str(sd * SD))
print("maka hasil indek tidak dik adalah: " + str(tdk * TDK))
print()
print("====soal no3 =====")

S2s =   0.25
S1s =   0.2
SMA = 0.15
SMP =   0.10
SD =    0.05
TDK= 0.03

s2_1 = 0 * S2s
s1_1    = 4 * S1s
sma_1 = 12 * SMA
smp_1   =   5 * SMP
sd_1    =   1 * SD
tdk_1 = 2 * TDK

s2_2 = 1 * S2s
s1_2    = 12 * S1s
sma_2 = 17 * SMA
smp_2   =   6 * SMP
sd_2    =   8 * SD
tdk_2 = 14 * TDK

s2_3 = 4 * S2s
s1_3    = 6 * S1s
sma_3 = 5 * SMA
smp_3   =   15 * SMP
sd_3    =   0 * SD
tdk_3 = 3 * TDK

s2_4 = 7 * S2s
s1_4    = 13 * S1s
sma_4 = 20 * SMA
smp_4   =   5 * SMP
sd_4    =   1 * SD
tdk_4 = 2 * TDK

s2_5 = 5 * S2s
s1_5    = 14 * S1s
sma_5 = 11 * SMA
smp_5   =   20 * SMP
sd_5    =   10 * SD
tdk_5 = 0 * TDK

s2_6 = 0 * S2s
s1_6    = 0 * S1s
sma_6 = 75 * SMA
smp_6   =   15 * SMP
sd_6    =   1 * SD
tdk_6 = 1 * TDK
h = ((s2_1) + (s1_1) + (sma_1) + (smp_1) + (sd_1) + (tdk_1))
h2 = ((s2_2) + (s1_2) + (sma_2) + (smp_2) + (sd_2) + (tdk_2))
h3 = ((s2_3) + (s1_3) + (sma_3) + (smp_3) + (sd_3) + (tdk_3))
h4 = ((s2_4) + (s1_4) + (sma_4) + (smp_4) + (sd_4) + (tdk_4))
h5 = ((s2_5) + (s1_5) + (sma_5) + (smp_5) + (sd_5) + (tdk_5))
h6 = ((s2_6) + (s1_6) + (sma_6) + (smp_6) + (sd_6) + (tdk_6))

print("usia >70: ")
print("maka hasil bobot s2: " +str(s2_1))
print("maka hasil bobot s1: " +str(s1_1))
print("maka hasil bobot sma: " +str(sma_1))
print("maka hasil bobot smp: " +str(smp_1))
print("maka hasil bobot sd: " +str(sd_1))
print("maka hasil bobot tdk: " +str(tdk_1))
print("makan indexnyah adalah: " + str(h))
print()

print("usia >60: ")
print("maka hasil bobot s2: " +str(s2_2))
print("maka hasil bobot s1: " +str(s1_2))
print("maka hasil bobot sma: " +str(sma_2))
print("maka hasil bobot smp: " +str(smp_2))
print("maka hasil bobot sd: " +str(sd_2))
print("maka hasil bobot tdk: " +str(tdk_2))
print("makan indexnyah adalah: " + str(h2))
print()
print("usia >50: ")
print("maka hasil bobot s2: " +str(s2_3))
print("maka hasil bobot s1: " +str(s1_3))
print("maka hasil bobot sma: " +str(sma_3))
print("maka hasil bobot smp: " +str(smp_3))
print("maka hasil bobot sd: " +str(sd_3))
print("maka hasil bobot tdk: " +str(tdk_3))
print("makan indexnyah adalah: " + str(h3))
print()

print("usia >40: ")
print("maka hasil bobot s2: " +str(s2_4))
print("maka hasil bobot s1: " +str(s1_4))
print("maka hasil bobot sma: " +str(sma_4))
print("maka hasil bobot smp: " +str(smp_4))
print("maka hasil bobot sd: " +str(sd_4))
print("maka hasil bobot tdk: " +str(tdk_4))
print("makan indexnyah adalah: " + str(h4))
print()
print("usia >30: ")
print("maka hasil bobot s2: " +str(s2_5))
print("maka hasil bobot s1: " +str(s1_5))
print("maka hasil bobot sma: " +str(sma_5))
print("maka hasil bobot smp: " +str(smp_5))
print("maka hasil bobot sd: " +str(sd_5))
print("maka hasil bobot tdk: " +str(tdk_5))
print("makan indexnyah adalah: " + str(h5))
print()
print("usia >20: ")
print("maka hasil bobot s2: " +str(s2_6))
print("maka hasil bobot s1: " +str(s1_6))
print("maka hasil bobot sma: " +str(sma_6))
print("maka hasil bobot smp: " +str(smp_6))
print("maka hasil bobot sd: " +str(sd_6))
print("maka hasil bobot tdk: " +str(tdk_6))
print("makan indexnyah adalah: " + str(h6))
print()

print("===soal no4 =====")
print()
usia = (">70",">60",">50",">40",">30",">20")
max = 3.2099999999999995
print("Pada Usia Berapakah dengan indeks mutu pendidikan paling kecil: " + usia[0] +" dengan nilai: "+ str(max))
print()
print("====soal no 5 ====")

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang di setiap pendidikan")
jurusan = ["s2","s1","sma","smp","sd","tdk"]
siswa = [17,49,140,70,39,30]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["s2","s1","sma","smp","sd","tdk"]
siswa = [17,49,140,70,39,30]
c = ['red','yellow','blue']
plt.title("jumlah orang di setiap pendidikan")
ax.bar(jurusan,siswa,color=c)
plt.show()
print()

import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Berdasarkan rentang usia")
jurusan = ["u70","u60","u50","u40","u30","u20"]
siswa = [24,58,33,78,60,92]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ["u70","u60","u50","u40","u30","u20"]
siswa = [24,58,33,78,60,92]
c = ['red','yellow','blue']
plt.title("Berdasarkan rentang usia")
ax.bar(jurusan,siswa,color=c)
plt.show()
# Out:
# ===soal no1=====
# jumlah s2: 17
# jumlah s1: 49
# jumlah sma: 140
# jumlah smp: 70
# jumlah sd: 39
# jumlah tdk: 30
#
# ====soal no2======
# maka hasil indek s2 adalah: 4.25
# maka hasil indek s1 adalah: 9.8
# maka hasil indek sma adalah: 21.0
# maka hasil indek smp adalah: 7.0
# maka hasil indek sd adalah: 1.9500000000000002
# maka hasil indek tidak dik adalah: 0.8999999999999999
#
# ====soal no3 =====
# usia >70:
# maka hasil bobot s2: 0.0
# maka hasil bobot s1: 0.8
# maka hasil bobot sma: 1.7999999999999998
# maka hasil bobot smp: 0.5
# maka hasil bobot sd: 0.05
# maka hasil bobot tdk: 0.06
# makan indexnyah adalah: 3.2099999999999995
#
# usia >60:
# maka hasil bobot s2: 0.25
# maka hasil bobot s1: 2.4000000000000004
# maka hasil bobot sma: 2.55
# maka hasil bobot smp: 0.6000000000000001
# maka hasil bobot sd: 0.4
# maka hasil bobot tdk: 0.42
# makan indexnyah adalah: 6.620000000000001
#
# usia >50:
# maka hasil bobot s2: 1.0
# maka hasil bobot s1: 1.2000000000000002
# ...
