# %%
burger =	24000
pizza =	52000
dimsum =	30000
ekkado =	7500
milkshake =	10000
eskrim =	15000

burger1 = 6
pizza1 = 3
dimsum1 = 4
ekkado1 = 4
milkshake1 = 2
eskrim1 = 5
print("=======soal no1=======")
pesan = ((burger * burger1) + (pizza * pizza1) + (dimsum * dimsum1) + (ekkado * ekkado1) + (milkshake * milkshake1) + (eskrim * eskrim1))
print ("maka belanjaan semuanyah adalah: Rp." + str(pesan))
jb =(burger1 + pizza1 + dimsum1 + ekkado1 + milkshake1 + eskrim1)
print("jumlah semua belanjaan "+ str(jb))
print()
print("=======soal no2=======")

j1 = (burger1 / jb) * 100
j2 = (pizza1 / jb) * 100
j3 = (dimsum1 / jb) * 100
j4 = (ekkado1 / jb) * 100
j5 = (milkshake1 / jb) * 100
j6 = (eskrim1 / jb) * 100

print("burger: " + str(j1))
print("pizza: " + str(j2))
print("dimsum: " + str(j3))
print("ekkado: " + str(j4))
print("milkshake: " + str(j5))
print("eskrim: " + str(j6))
print()
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("jumlah orang di setiap pendidikan")
jurusan = ["burger","pizza","dimsum","ekkado","milkshake","eskrim"]
siswa = [0.25,0.125,0.16666666666666666,0.16666666666666666,0.08333333333333333,0.20833333333333334]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')

plt.show()
print()
print("=======soal no3=======")
print("ahmad")
a1 = 4
b1 = 2
jr = 7.5
ong = 2000 
ahmad = (0.70 * ((a1 * burger) + (b1  * pizza)) + (jr * ong)) - 5000
print ("pesanana ahmad: Rp." +str(ahmad))
kb3 = 200000 - ahmad
print ("maka kembalian ahmad: " +str(kb3))
print()
print("beni")
a2 = 3
b2 = 1
c1 =2
jr1 = 4
ong1 = 1800 
beni = (0.70 * ((a2 * dimsum) + (b2  * eskrim) + (c1 * milkshake)) + (jr1 * ong1)) - 5000
print ("pesanana ahmad: Rp." +str(beni))
kb4 = 150000 - beni
print ("maka kembalian beni: " +str(kb4))
print()
print("citra")
a3 = 3
jr2 = 8
ong2 = 2000 
citra = ((a3  * eskrim) + (jr2 * ong2)) - 5000
print ("pesanana ahmad: Rp." +str(citra))
kb2 = 60000- citra
print ("maka kembalian citra: " +str(kb2))
print()
print("dadang")
a4 = 2
b3 = 1
jr3 = 5
ong3 = 1800 
dadang = (0.80 * ((a4 * burger) + (b3  * dimsum)) + (jr3 * ong3)) - 5000
print ("pesanana ahmad: Rp." +str(dadang))
kb1 = 100000 - dadang
print ("maka kembalian dadang: " +str(kb1))
print()
print("epen")
a5 = 4
b4 = 1
c2 = 1
jr4 = 12
ong4 = 2200 
epen = (0.70 * ((a5 * ekkado) + (b4  * eskrim) + (c2 * pizza) ) + (jr4 * ong4)) - 5000
print ("potong epen: Rp." +str(epen))
kb = 100000 - epen
print ("maka kembalian epen: " +str(kb))
print()

print("=====soal no4======")

print("ahmad")
a1 = 4
b1 = 2
jr = 7.5
ong = 2000 
ahmad = (0.30 * ((a1 * burger) + (b1  * pizza))) + 5000
print ("potongan ahmad: Rp." +str(ahmad))
print("beni")
a2 = 3
b2 = 1
c1 =2
jr1 = 4
ong1 = 1800 
beni = (0.30 * ((a2 * dimsum) + (b2  * eskrim) + (c1 * milkshake))) + 5000
print ("potongan beni: Rp." +str(beni))

print("citra")
a3 = 3
jr2 = 8
ong2 = 2000 
citra = (0 *(a3  * eskrim) )+ 5000
print ("potongan citra: Rp." +str(citra))
print("dadang")
a4 = 2
b3 = 1
jr3 = 5
ong3 = 1800 
dadang = (0.20 * ((a4 * burger) + (b3  * dimsum))) + 5000
print ("potongan dadang: Rp." +str(dadang))
print("epen")
a5 = 4
b4 = 1
c2 = 1
jr4 = 12
ong4 = 2200 
epen = (0.30 * ((a5 * ekkado) + (b4  * eskrim) + (c2 * pizza) )) + 5000
print ("potong epen: Rp." +str(epen))
sm = (ahmad + beni + citra + dadang + epen)
print ("makan total semua potongan " +str(sm))
print()
print("======soal no5========")
a = 7.5
b = 2000
c = 4
d = 1800
e = 8
f = 2000
g = 5
h = 1800
i = 12
j = 2200
smu = ((a * b)+(c * d)+(e * f)+(g * h)+(i * j))
print("maka ongkir semua pembelian adalah: "+str(smu))
# Out:
# =======soal no1=======
# maka belanjaan semuanyah adalah: Rp.545000
# jumlah semua belanjaan 24
#
# =======soal no2=======
# burger: 25.0
# pizza: 12.5
# dimsum: 16.666666666666664
# ekkado: 16.666666666666664
# milkshake: 8.333333333333332
# eskrim: 20.833333333333336
# =======soal no3=======
# ahmad
# pesanana ahmad: Rp.150000.0
# maka kembalian ahmad: 50000.0
#
# beni
# pesanana ahmad: Rp.89700.0
# maka kembalian beni: 60300.0
#
# citra
# pesanana ahmad: Rp.56000
# maka kembalian citra: 4000
#
# dadang
# pesanana ahmad: Rp.66400.0
# maka kembalian dadang: 33600.0
#
# epen
# potong epen: Rp.89300.0
# maka kembalian epen: 10700.0
#
# =====soal no4======
# ahmad
# potongan ahmad: Rp.65000.0
# beni
# potongan beni: Rp.42500.0
# citra
# potongan citra: Rp.5000
# dadang
# potongan dadang: Rp.20600.0
# epen
# potong epen: Rp.34100.0
# makan total semua potongan 167200.0
#
# ======soal no5========
# maka ongkir semua pembelian adalah: 73600.0
